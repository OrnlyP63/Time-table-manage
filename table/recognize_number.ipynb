# %%
import tensorflow as tf
from tensorflow import keras

# %%
mnist = keras.datasets.mnist

# %%
(x_train, y_train),(x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 4s 0us/step

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy')>0.99):
            print("\nReached 99.0% accuracy so cancelling training!")
            self.model.stop_training = True

# %%
model.fit(x_train,
          y_train,
          epochs=50,
          callbacks=[myCallback()])
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.1097 - accuracy: 0.9668
# Epoch 2/50
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.0888 - accuracy: 0.9728
# Epoch 3/50
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.0762 - accuracy: 0.9756
# Epoch 4/50
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.0682 - accuracy: 0.9777
# Epoch 5/50
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.0581 - accuracy: 0.9817
# Epoch 6/50
# 60000/60000 [==============================] - 5s 92us/sample - loss: 0.0529 - accuracy: 0.9823
# Epoch 7/50
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.0473 - accuracy: 0.9845
# Epoch 8/50
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.0457 - accuracy: 0.9850
# Epoch 9/50
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.0413 - accuracy: 0.9865
# Epoch 10/50
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.0393 - accuracy: 0.9870
# Epoch 11/50
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.0368 - accuracy: 0.9873
# Epoch 12/50
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.0332 - accuracy: 0.9886
# Epoch 13/50
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.0332 - accuracy: 0.9887
# Epoch 14/50
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.0306 - accuracy: 0.9896
# Epoch 15/50
# 59936/60000 [============================>.] - ETA: 0s - loss: 0.0305 - accuracy: 0.9901
# Reached 99.0% accuracy so cancelling training!
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.0305 - accuracy: 0.9901

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.07525893582784048, 0.9811]

# %%
tf.saved_model.save(model, "./models/mnist")
# Out:
# INFO:tensorflow:Assets written to: ./models/mnist\assets

# %%
converter = tf.lite.TFLiteConverter.from_saved_model("models/mnist")
tflite_model = converter.convert()
# Out:
# ---------------------------------------------------------------------------
# ConverterError                            Traceback (most recent call last)
# <ipython-input-51-4bb7d4268cbb> in <module>
#       1 converter = tf.lite.TFLiteConverter.from_saved_model("models/mnist")
# ----> 2 tflite_model = converter.convert()
#
# ~\Anaconda3\envs\AIML\lib\site-packages\tensorflow_core\lite\python\lite.py in convert(self)
#     444         input_tensors=input_tensors,
#     445         output_tensors=output_tensors,
# --> 446         **converter_kwargs)
#     447
#     448     if self._is_calibration_quantize():
#
# ~\Anaconda3\envs\AIML\lib\site-packages\tensorflow_core\lite\python\convert.py in toco_convert_impl(input_data, input_tensors, output_tensors, enable_mlir_converter, *args, **kwargs)
#     447       input_data.SerializeToString(),
#     448       debug_info_str=debug_info_str,
# --> 449       enable_mlir_converter=enable_mlir_converter)
#     450   return data
#     451
#
# ~\Anaconda3\envs\AIML\lib\site-packages\tensorflow_core\lite\python\convert.py in toco_convert_protos(model_flags_str, toco_flags_str, input_data_str, debug_info_str, enable_mlir_converter)
#     198       stdout = _try_convert_to_unicode(stdout)
#     199       stderr = _try_convert_to_unicode(stderr)
# --> 200       raise ConverterError("See console for info.\n%s\n%s\n" % (stdout, stderr))
#     201   finally:
#     202     # Must manually cleanup files.
#
# ConverterError: See console for info.
# 'toco_from_protos' is not recognized as an internal or external command,
# operable program or batch file.
